# %% [markdown]
# ## Final Project - Amazon Ranking Analysis
# Group Member:-
# 1. Abdullah Ghazali
# 1. Abdullah Amir Ikram
# 1. Azri Soufi

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#read csv file
amazon = pd.read_csv('amazon.csv')
amazon.head()
# Out:
#    Index                                        ProductName  ScrapeDate  \
# 0      0  #1 BEST Probiotic Supplement - 60 Day Supply w...  2016-06-14
# 1      1  #1 BEST Probiotic Supplement - 60 Day Supply w...  2016-06-14
# 2      2  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
# 3      3  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
# 4      4  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
#
#    ScrapedIndex  ScrapedIndexTrueRank  CorrectedIndexTrueRank  \
# 0             2                     2                       1
# 1             1                     1                       2
# 2             1                     1                       1
# 3             2                     1                       1
# 4             3                     1                       1
#
#    ScrapedIndexPrice  CorrectedPrice   ScrapedIndexVendor  \
# 0              20.99           20.99  Supplement Warriors
# 1              19.99           25.02      Sharp Nutrition
# 2               3.96            3.96         speedy tests
# 3               3.96            3.96   Drug Abuse Control
# 4               3.96            3.96  Lowest Priced Tests
#
#   ScrapedIndexVendorType  BBScrapedPrice BBVendorType  \
# 0                  Other            -1.0          FBA
# 1                    FBA            -1.0          FBA
# 2                  Other             4.9          FBA
# 3                  Other             4.9          FBA
# 4                  Other             4.9          FBA
#
#                                            BBVendor  BBCorrectedPrice
# 0  Sold by Sharp Nutrition and Fulfilled by Amazon.             25.02
# 1  Sold by Sharp Nutrition and Fulfilled by Amazon.             25.02
# 2  Sold by Michael Minyety and Fulfilled by Amazon.              9.97
# 3  Sold by Michael Minyety and Fulfilled by Amazon.              9.97
# 4  Sold by Michael Minyety and Fulfilled by Amazon.              9.97

# %%
#View row and column of dataset
amazon.shape
# Out:
# (6973, 14)

# %%
#view datatype of each column
amazon.dtypes
# Out:
# Index                       int64
# ProductName                object
# ScrapeDate                 object
# ScrapedIndex                int64
# ScrapedIndexTrueRank        int64
# CorrectedIndexTrueRank      int64
# ScrapedIndexPrice         float64
# CorrectedPrice            float64
# ScrapedIndexVendor         object
# ScrapedIndexVendorType     object
# BBScrapedPrice            float64
# BBVendorType               object
# BBVendor                   object
# BBCorrectedPrice          float64
# dtype: object

# %%
#view statistic overview of dataset
amazon.describe()
# Out:
#              Index  ScrapedIndex  ScrapedIndexTrueRank  \
# count  6973.000000   6973.000000           6973.000000
# mean   3486.000000     25.041876             22.730962
# std    2013.076046     23.618871             20.520442
# min       0.000000      1.000000              1.000000
# 25%    1743.000000      8.000000              7.000000
# 50%    3486.000000     17.000000             16.000000
# 75%    5229.000000     35.000000             33.000000
# max    6972.000000    162.000000            113.000000
#
#        CorrectedIndexTrueRank  ScrapedIndexPrice  CorrectedPrice  \
# count             6973.000000        6973.000000     6973.000000
# mean                21.559300          54.904896       55.567631
# std                 19.154709          74.293356       74.476092
# min                  1.000000           2.380000        2.380000
# 25%                  7.000000          19.530000       20.010000
# 50%                 16.000000          31.900000       32.080000
# 75%                 31.000000          55.890000       56.100000
# max                107.000000         931.800000      931.800000
#
#        BBScrapedPrice  BBCorrectedPrice
# count     6973.000000       6973.000000
# mean        36.295817         45.827961
# std         61.838063         63.889925
# min         -1.000000          0.000000
# 25%          8.990000         15.790000
# 50%         14.940000         23.340000
# 75%         36.990000         47.920000
# max        698.000000        706.110000

# %%
#check missing value
amazon.isnull().sum()
# Out:
# Index                       0
# ProductName                 0
# ScrapeDate                  0
# ScrapedIndex                0
# ScrapedIndexTrueRank        0
# CorrectedIndexTrueRank      0
# ScrapedIndexPrice           0
# CorrectedPrice              0
# ScrapedIndexVendor          0
# ScrapedIndexVendorType      0
# BBScrapedPrice              0
# BBVendorType                0
# BBVendor                  164
# BBCorrectedPrice            0
# dtype: int64

# %%
#view missing value in DataFrame
amazon[amazon.BBVendor.isnull()]
# Out:
#       Index                                        ProductName  ScrapeDate  \
# 19       19  2wayz FULL METAL BODY Garden Hose Splitter | Y...  2016-06-20
# 20       20  2wayz FULL METAL BODY Garden Hose Splitter | Y...  2016-06-20
# 1367   1367  Bushnell Powerview 7-15X25 Compact Zoom Binocular  2016-08-30
# 1368   1368  Bushnell Powerview 7-15X25 Compact Zoom Binocular  2016-08-30
# 1369   1369  Bushnell Powerview 7-15X25 Compact Zoom Binocular  2016-08-30
# ...     ...                                                ...         ...
# 5658   5658                   Regalo Swing Down Bedrail, White  2016-06-27
# 5659   5659                   Regalo Swing Down Bedrail, White  2016-06-27
# 5660   5660                   Regalo Swing Down Bedrail, White  2016-06-27
# 5661   5661                   Regalo Swing Down Bedrail, White  2016-06-27
# 5899   5899  Samsung Galaxy Tab A 8-Inch Tablet (Wi-Fi)(16 ...  2016-06-29
#
#       ScrapedIndex  ScrapedIndexTrueRank  CorrectedIndexTrueRank  \
# 19               1                     1                       1
# 20               2                     2                       2
# 1367             1                     1                       1
# 1368             2                     2                       2
# 1369             3                     3                       3
# ...            ...                   ...                     ...
# 5658            20                    19                      19
# 5659            21                    20                      20
# 5660            22                    21                      21
# 5661            23                    22                      22
# 5899             1                     1                       1
#
#       ScrapedIndexPrice  CorrectedPrice    ScrapedIndexVendor  \
# 19                40.00           40.00              Irtenzia
# 20                54.94           54.94             Mild Shop
# 1367              53.04           53.04          PORTABLE GUY
# 1368              54.41           54.41           TheXBOXking
# 1369              54.69           54.69             WebyShops
# ...                 ...             ...                   ...
# 5658              44.96           44.96             Mild Shop
# 5659              47.79           47.79  MidwestProductsDepot
# 5660              47.90           47.90           Fairy Bless
# 5661              53.96           53.96              RevoSync
# 5899             199.00          199.00    Electronic Express
#
#      ScrapedIndexVendorType  BBScrapedPrice BBVendorType BBVendor  \
# 19                    Other            -1.0            O      NaN
# 20                    Other            -1.0            O      NaN
# 1367                  Other            -1.0            O      NaN
# 1368                  Other            -1.0            O      NaN
# 1369                  Other            -1.0            O      NaN
# ...                     ...             ...          ...      ...
# 5658                  Other            -1.0            O      NaN
# 5659                  Other            -1.0            O      NaN
# 5660                  Other            -1.0            O      NaN
# 5661                  Other            -1.0            O      NaN
# 5899                  Other            -1.0            O      NaN
#
#       BBCorrectedPrice
# 19                9.97
# 20                9.97
# 1367            165.50
# 1368            165.50
# 1369            165.50
# ...                ...
# 5658             35.34
# 5659             35.34
# 5660             35.34
# 5661             35.34
# 5899             15.27
#
# [164 rows x 14 columns]

# %%
#display correlation of each fields of dataset
amazon.corr()
# Out:
#                            Index  ScrapedIndex  ScrapedIndexTrueRank  \
# Index                   1.000000     -0.041440             -0.041483
# ScrapedIndex           -0.041440      1.000000              0.986999
# ScrapedIndexTrueRank   -0.041483      0.986999              1.000000
# CorrectedIndexTrueRank -0.052926      0.861782              0.897189
# ScrapedIndexPrice      -0.081656      0.033243              0.033702
# CorrectedPrice         -0.081318      0.026051              0.026145
# BBScrapedPrice         -0.062443     -0.040437             -0.048845
# BBCorrectedPrice       -0.072889     -0.051168             -0.059107
#
#                         CorrectedIndexTrueRank  ScrapedIndexPrice  \
# Index                                -0.052926          -0.081656
# ScrapedIndex                          0.861782           0.033243
# ScrapedIndexTrueRank                  0.897189           0.033702
# CorrectedIndexTrueRank                1.000000           0.046877
# ScrapedIndexPrice                     0.046877           1.000000
# CorrectedPrice                        0.041911           0.999510
# BBScrapedPrice                       -0.047200           0.948636
# BBCorrectedPrice                     -0.057569           0.967543
#
#                         CorrectedPrice  BBScrapedPrice  BBCorrectedPrice
# Index                        -0.081318       -0.062443         -0.072889
# ScrapedIndex                  0.026051       -0.040437         -0.051168
# ScrapedIndexTrueRank          0.026145       -0.048845         -0.059107
# CorrectedIndexTrueRank        0.041911       -0.047200         -0.057569
# ScrapedIndexPrice             0.999510        0.948636          0.967543
# CorrectedPrice                1.000000        0.949922          0.968685
# BBScrapedPrice                0.949922        1.000000          0.970268
# BBCorrectedPrice              0.968685        0.970268          1.000000

# %% [markdown]
# Since, 'Index' column does not give us any impact on our analysis we can remove it from the data frame

# %%
# remove Index column
amazon.drop('Index', axis = 1, inplace = True)

# %%
amazon.shape
# Out:
# (6973, 13)

# %% [markdown]
# In the process below, we change object data type into 'int' data type since Machine Learning Models can not work on categorical variables in the form of strings, so we need to change it into numerical form.

# %%
amazon.groupby('BBVendorType').BBVendor.count()
# Out:
# BBVendorType
# Amazon    5788
# FBA        470
# O          551
# Name: BBVendor, dtype: int64

# %%
amazon.groupby('ScrapedIndexVendorType').ScrapedIndexVendorType.count()
# Out:
# ScrapedIndexVendorType
# Amazon     192
# FBA        409
# Other     6372
# Name: ScrapedIndexVendorType, dtype: int64

# %%
amazon['BBVendorType'] = amazon.BBVendorType.map({'Amazon':1, 'FBA':2, 'O': 3})

# %%
amazon.head()
# Out:
#                                          ProductName  ScrapeDate  \
# 0  #1 BEST Probiotic Supplement - 60 Day Supply w...  2016-06-14
# 1  #1 BEST Probiotic Supplement - 60 Day Supply w...  2016-06-14
# 2  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
# 3  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
# 4  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
#
#    ScrapedIndex  ScrapedIndexTrueRank  CorrectedIndexTrueRank  \
# 0             2                     2                       1
# 1             1                     1                       2
# 2             1                     1                       1
# 3             2                     1                       1
# 4             3                     1                       1
#
#    ScrapedIndexPrice  CorrectedPrice   ScrapedIndexVendor  \
# 0              20.99           20.99  Supplement Warriors
# 1              19.99           25.02      Sharp Nutrition
# 2               3.96            3.96         speedy tests
# 3               3.96            3.96   Drug Abuse Control
# 4               3.96            3.96  Lowest Priced Tests
#
#   ScrapedIndexVendorType  BBScrapedPrice  BBVendorType  \
# 0                  Other            -1.0             2
# 1                    FBA            -1.0             2
# 2                  Other             4.9             2
# 3                  Other             4.9             2
# 4                  Other             4.9             2
#
#                                            BBVendor  BBCorrectedPrice
# 0  Sold by Sharp Nutrition and Fulfilled by Amazon.             25.02
# 1  Sold by Sharp Nutrition and Fulfilled by Amazon.             25.02
# 2  Sold by Michael Minyety and Fulfilled by Amazon.              9.97
# 3  Sold by Michael Minyety and Fulfilled by Amazon.              9.97
# 4  Sold by Michael Minyety and Fulfilled by Amazon.              9.97

# %%
amazon['ScrapedIndexVendorType'] = amazon.ScrapedIndexVendorType.map({'Amazon':1, 'FBA':2, 'Other': 3})

# %%
amazon.head()
# Out:
#                                          ProductName  ScrapeDate  \
# 0  #1 BEST Probiotic Supplement - 60 Day Supply w...  2016-06-14
# 1  #1 BEST Probiotic Supplement - 60 Day Supply w...  2016-06-14
# 2  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
# 3  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
# 4  10 Panel Dip Drug Testing Kit, Test for 10 Dif...  2016-06-27
#
#    ScrapedIndex  ScrapedIndexTrueRank  CorrectedIndexTrueRank  \
# 0             2                     2                       1
# 1             1                     1                       2
# 2             1                     1                       1
# 3             2                     1                       1
# 4             3                     1                       1
#
#    ScrapedIndexPrice  CorrectedPrice   ScrapedIndexVendor  \
# 0              20.99           20.99  Supplement Warriors
# 1              19.99           25.02      Sharp Nutrition
# 2               3.96            3.96         speedy tests
# 3               3.96            3.96   Drug Abuse Control
# 4               3.96            3.96  Lowest Priced Tests
#
#    ScrapedIndexVendorType  BBScrapedPrice  BBVendorType  \
# 0                       3            -1.0             2
# 1                       2            -1.0             2
# 2                       3             4.9             2
# 3                       3             4.9             2
# 4                       3             4.9             2
#
#                                            BBVendor  BBCorrectedPrice
# 0  Sold by Sharp Nutrition and Fulfilled by Amazon.             25.02
# 1  Sold by Sharp Nutrition and Fulfilled by Amazon.             25.02
# 2  Sold by Michael Minyety and Fulfilled by Amazon.              9.97
# 3  Sold by Michael Minyety and Fulfilled by Amazon.              9.97
# 4  Sold by Michael Minyety and Fulfilled by Amazon.              9.97

# %%
#To visualise the correlation among the header.
#The darkest color has lowest to none colleration where the brightest has highest colleration
plt.subplots(figsize=(10,8))
sns.heatmap(amazon.corr(), annot=True,)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From heatmap above, we can see that 'ScrapedIndexPrice' and 'CorrectedPrice' are highly correlated. Also for 'BBCorrectedPrice' and 'BBScrapedPrice' are highly correlated

# %% [markdown]
# For next step, we want to analyse more relationship among all variable. We want to handle missing and duplicate value. Then, we want to perform machine learning to predict the product price
